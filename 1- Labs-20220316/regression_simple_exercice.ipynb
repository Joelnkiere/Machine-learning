# %% [markdown]
# ## Exercice Machine Learning Regression Simple Avec un seul feature

# %%
# !uv pip install matplotlib pandas --system-certs
# Out:
# Using Python 3.13.13 environment at: C:\joe\myVenv
# Checked 2 packages in 147ms

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("FuelConsumption.csv")

# %%
#afficher les infos du dataset à partir de la tete en precisant le nombre de ligne
df.head(10)
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
# 5       2014  ACURA         RLX     MID-SIZE         3.5          6
# 6       2014  ACURA          TL     MID-SIZE         3.5          6
# 7       2014  ACURA      TL AWD     MID-SIZE         3.7          6
# 8       2014  ACURA      TL AWD     MID-SIZE         3.7          6
# 9       2014  ACURA         TSX      COMPACT         2.4          4
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# ...

# %%
df.info() #affiche les infos
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   str
#  2   MODEL                     1067 non-null   str
#  3   VEHICLECLASS              1067 non-null   str
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   str
#  7   FUELTYPE                  1067 non-null   str
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), str(5)
# memory usage: 108.5 KB

# %%
df.columns
# Out:
# Index(['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUELTYPE', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='str')

# %%
cdf=df[['ENGINESIZE', 'CYLINDERS',
       'TRANSMISSION', 'CO2EMISSIONS','FUELCONSUMPTION_COMB']]
cdf.head(9)
# quand on a deux crochets c'est un dataframe: un tableau multidimensionnel (un
# Out:
#    ENGINESIZE  CYLINDERS TRANSMISSION  CO2EMISSIONS  FUELCONSUMPTION_COMB
# 0         2.0          4          AS5           196                   8.5
# 1         2.4          4           M6           221                   9.6
# 2         1.5          4          AV7           136                   5.9
# 3         3.5          6          AS6           255                  11.1
# 4         3.5          6          AS6           244                  10.6
# 5         3.5          6          AS6           230                  10.0
# 6         3.5          6          AS6           232                  10.1
# 7         3.7          6          AS6           255                  11.1
# 8         3.7          6           M6           267                  11.6

# %%
plt.figure(figsize=(8,5))
plt.scatter(cdf.ENGINESIZE, cdf.CO2EMISSIONS,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter(cdf.FUELCONSUMPTION_COMB, cdf.CO2EMISSIONS,  color='blue')
plt.xlabel("FUELCONSUMPTION_COMB")
plt.ylabel("Emission")
plt.show()

# %%
print(np.random.rand(len(df)) < 0.8)
# Out:
# [False  True False ...  True False False]

# %%
print(len(df), len(np.random.rand(len(df)) < 0.8))
# Out:
# 1067 1067

# %%
#added by me
print(np.random.rand(len(df)) < 0.8)
print(len(df), len(np.random.rand(len(df)) < 0.8))
print(np.random.randn(10))
print(np.random.rand(10))
print(np.random.rand(10) < 0.8)
msk = np.random.rand(len(df)) < 0.8
# Out:
# [ True  True  True ...  True  True  True]
# 1067 1067
# [-0.62598946 -1.61419198  0.05801143 -1.28771369  0.27720755  0.92404506
#   0.61811631  0.71529321  0.34255917  0.56669734]
# [0.88694699 0.31062974 0.27995227 0.82131841 0.03150115 0.34419878
#  0.61438288 0.32050165 0.73604196 0.67807041]
# [ True  True  True  True  True  True  True  True  True  True]

# %%
print((np.random.rand(10) < 0.8)==True)
# Out:
# [ True  True  True False False  True False  True  True  True]

# %%
msk = np.random.rand(len(df)) < 0.8
print(msk[msk==True])
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
# ...

# %%
# !uv pip install scikit-learn --system-certs
# Out:
# Using Python 3.13.13 environment at: C:\joe\myVenv
# Resolved 6 packages in 2.11s
# Prepared 5 packages in 14.51s
# Installed 5 packages in 2.02s
#  + joblib==1.5.3
#  + narwhals==2.22.1
#  + scikit-learn==1.9.0
#  + scipy==1.18.0
#  + threadpoolctl==3.6.0

# %%
msk = np.random.rand(len(df)) < 0.8
train = cdf[msk]
test = cdf[~msk]

# %%
plt.scatter(train.ENGINESIZE, train.CO2EMISSIONS,  color='blue')

# %%
plt.scatter(train.ENGINESIZE, train.CO2EMISSIONS,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.show()

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['ENGINESIZE']])
train_y = np.asanyarray(train[['CO2EMISSIONS']])
# added by me, or 
#regr.fit(train[['ENGINESIZE']], train[['CO2EMISSIONS']])
regr.fit(train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[39.21968296]]
# Intercept:  [125.05269723]

# %%
plt.scatter(train.ENGINESIZE, train.CO2EMISSIONS,  color='blue')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
plt.xlabel("Engine size")
plt.ylabel("Emission")
# Out:
# Text(0, 0.5, 'Emission')
